# %%
from langchain_community.chat_models import ChatZhipuAI
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

import os

os.environ["ZHIPUAI_API_KEY"] = "967bf1087dbc4faca0c8286443b5d7a5.Oys89JDnjgfe86ja"

chat = ChatZhipuAI(
    model="glm-4",
    temperature=0.5,  # 模型温度， 值在0-1之间。 值越小，随机性越低
)

messages = [
    SystemMessage(content="你是一个助手，请用中文回复"),
    HumanMessage(content="夏天适合吃什么水果?"),
]

response = chat.invoke(messages)
print(response.content)
# Out:
# 夏天适合吃多种水果，以下是一些推荐：
#
# 1. 西瓜 - 夏天的代表水果，水分充足，能解暑降温
# 2. 哈密瓜 - 甜度高，水分多，富含维生素
# 3. 葡萄 - 含有多种抗氧化物质，有助于消暑
# 4. 桃子 - 水分丰富，味道甜美
# 5. 荔枝 - 虽然热量较高，但能快速补充能量
# 6. 芒果 - 富含维生素A和C，对皮肤有益
# 7. 蓝莓 - 抗氧化能力强，有助于保护视力
# 8. 柠檬 - 可以泡水喝，补充维生素C，提神醒脑
# 9. 猕猴桃 - 维生素C含量极高，有助于增强免疫力
# 10. 樱桃 - 含铁量高，有助于补血
#
# 这些水果大多水分含量高，能帮助身体在炎热的夏天保持水分平衡，同时提供丰富的维生素和矿物质。建议根据个人喜好和身体状况选择食用。
